# %% [markdown]
# <a href="https://colab.research.google.com/github/mingyukim-ai/AIMC2023/blob/main/stylegan2ada_handson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#할당된 gpu 확인
# !nvidia-smi

# 런타임 유형을 GPU로 설정하지 않으면 아래 문구가 뜸
#NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.
# Out:
# Fri Jan  6 12:40:35 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#현재 경로에 있는 파일이 무엇이 있는지 확인해보기(아래 코드를 받고 난 후와 비교)
# !ls
# Out:
# sample_data

# %%
# stylegan2-ada pytorch 공개 코드 가져오기
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 128, done.
# remote: Total 128 (delta 0), reused 0 (delta 0), pack-reused 128
# Receiving objects: 100% (128/128), 1.12 MiB | 1.18 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %% [markdown]
# ###### 코드 공식 사이트 구글에서 검색해서 확인해보기
# https://github.com/NVlabs/stylegan2-ada-pytorch

# %%
#가져온 코드 확인하기
# !ls
# Out:
# sample_data  stylegan2-ada-pytorch

# %%
#작업 위치를 코드 아래와 옮기기
import os
os.chdir('./stylegan2-ada-pytorch/')

# %%
# !ls
# Out:
# calc_metrics.py  docker_run.sh	LICENSE.txt   style_mixing.py
# dataset_tool.py  docs		metrics       torch_utils
# dnnlib		 generate.py	projector.py  training
# Dockerfile	 legacy.py	README.md     train.py

# %%
#필요한 파이썬 라이브러리 설치하기
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (4.64.1)
# Collecting pyspng
#   Downloading pyspng-0.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (205 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.9/205.9 KB 18.0 MB/s eta 0:00:00
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 18.1 MB/s eta 0:00:00
# Collecting imageio-ffmpeg==0.4.3
#   Downloading imageio_ffmpeg-0.4.3-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 54.4 MB/s eta 0:00:00
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pyspng) (1.21.6)
# Installing collected packages: ninja, pyspng, imageio-ffmpeg
# Successfully installed imageio-ffmpeg-0.4.3 ninja-1.11.1 pyspng-0.1.1

# %%
# !pip install torch==1.7.1 torchvision==0.8.2 torchaudio==0.7.2 torchtext==0.8.1 tensorboard==1.14.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.7.1
#   Downloading torch-1.7.1-cp38-cp38-manylinux1_x86_64.whl (776.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.8/776.8 MB 2.0 MB/s eta 0:00:00
# Collecting torchvision==0.8.2
#   Downloading torchvision-0.8.2-cp38-cp38-manylinux1_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 72.7 MB/s eta 0:00:00
# Collecting torchaudio==0.7.2
#   Downloading torchaudio-0.7.2-cp38-cp38-manylinux1_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 85.7 MB/s eta 0:00:00
# Collecting torchtext==0.8.1
#   Downloading torchtext-0.8.1-cp38-cp38-manylinux1_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 73.4 MB/s eta 0:00:00
# Collecting tensorboard==1.14.0
#   Downloading tensorboard-1.14.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 63.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.7.1) (4.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torch==1.7.1) (1.21.6)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from torchvision==0.8.2) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchtext==0.8.1) (2.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext==0.8.1) (4.64.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard==1.14.0) (3.19.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard==1.14.0) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard==1.14.0) (3.4.1)
# Requirement already satisfied: grpcio>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard==1.14.0) (1.51.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard==1.14.0) (1.3.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard==1.14.0) (57.4.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard==1.14.0) (1.15.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard==1.14.0) (1.0.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard==1.14.0) (5.2.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.8.1) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.8.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.8.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.8.1) (2022.12.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard==1.14.0) (3.11.0)
# Installing collected packages: torch, torchvision, torchtext, torchaudio, tensorboard
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.0+cu116
#     Uninstalling torchvision-0.14.0+cu116:
#       Successfully uninstalled torchvision-0.14.0+cu116
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.14.0
#     Uninstalling torchtext-0.14.0:
#       Successfully uninstalled torchtext-0.14.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.0+cu116
#     Uninstalling torchaudio-0.13.0+cu116:
#       Successfully uninstalled torchaudio-0.13.0+cu116
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires tensorboard<2.10,>=2.9, but you have tensorboard 1.14.0 which is incompatible.
# Successfully installed tensorboard-1.14.0 torch-1.7.1 torchaudio-0.7.2 torchtext-0.8.1 torchvision-0.8.2

# %%
#필요한 라이브러리 불러오기
import torch
torch.cuda.device_count()
import torchvision

# %%
#핸즈온에 필요한 데이터 가져오기(데이터 권한: 프로메디우스(주)의 데이터이며, 본 핸즈온용으로 무료 배포)
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1HYkn941NVvEtcHtQa_xcV-_xdB_E_Yyk' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1HYkn941NVvEtcHtQa_xcV-_xdB_E_Yyk" -O handson_stylegan2ada.zip && rm -rf ~/cookies.txt
# Out:
# --2023-01-06 12:42:40--  https://docs.google.com/uc?export=download&confirm=&id=1HYkn941NVvEtcHtQa_xcV-_xdB_E_Yyk
# Resolving docs.google.com (docs.google.com)... 172.217.194.102, 172.217.194.139, 172.217.194.113, ...
# Connecting to docs.google.com (docs.google.com)|172.217.194.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/smdeaaoafur75vfrpq04tegidltf4gv1/1673008950000/03948272884470799285/*/1HYkn941NVvEtcHtQa_xcV-_xdB_E_Yyk?e=download&uuid=21cc1cab-29aa-4ea3-b17d-cb24537a5fbb [following]
# Warning: wildcards not supported in HTTP.
# --2023-01-06 12:42:43--  https://doc-0c-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/smdeaaoafur75vfrpq04tegidltf4gv1/1673008950000/03948272884470799285/*/1HYkn941NVvEtcHtQa_xcV-_xdB_E_Yyk?e=download&uuid=21cc1cab-29aa-4ea3-b17d-cb24537a5fbb
# Resolving doc-0c-2o-docs.googleusercontent.com (doc-0c-2o-docs.googleusercontent.com)... 142.251.12.132, 2404:6800:4003:c11::84
# Connecting to doc-0c-2o-docs.googleusercontent.com (doc-0c-2o-docs.googleusercontent.com)|142.251.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13660491 (13M) [application/x-zip-compressed]
# Saving to: ‘handson_stylegan2ada.zip’
#
# handson_stylegan2ad 100%[===================>]  13.03M  --.-KB/s    in 0.05s
#
# 2023-01-06 12:42:44 (275 MB/s) - ‘handson_stylegan2ada.zip’ saved [13660491/13660491]

# %%
#받은 데이터 확인하기
# !ls
# Out:
# calc_metrics.py  docs			   metrics	    training
# dataset_tool.py  generate.py		   projector.py     train.py
# dnnlib		 handson_stylegan2ada.zip  README.md
# Dockerfile	 legacy.py		   style_mixing.py
# docker_run.sh	 LICENSE.txt		   torch_utils

# %%
#데이터 압축풀기(총 500장의 흉부 X-ray이미지이며 인공지능 생성모델로 만든 합성이미지임)
# !unzip handson_stylegan2ada.zip

# %%
#압축이 잘 풀렸는지 확인
# !ls
# Out:
# calc_metrics.py  docs			   LICENSE.txt	    torch_utils
# dataset_tool.py  generate.py		   metrics	    training
# dnnlib		 handson_stylegan2ada	   projector.py     train.py
# Dockerfile	 handson_stylegan2ada.zip  README.md
# docker_run.sh	 legacy.py		   style_mixing.py

# %%
# !ls handson_stylegan2ada
# Out:
# promedius_cxr_500_for_stylegan2ada_128pixel

# %%
imglist=os.listdir('handson_stylegan2ada/promedius_cxr_500_for_stylegan2ada_128pixel')#이미지 파일명을 imglist라는 변수에 담기
print(len(imglist))#이미지 개수 확인
print(imglist[:10])#샘플로 10개 이미지 파일명 확인
# Out:
# 500
# ['promedius_synthesized_cxr_001662.png', 'promedius_synthesized_cxr_001740.png', 'promedius_synthesized_cxr_001756.png', 'promedius_synthesized_cxr_001563.png', 'promedius_synthesized_cxr_001281.png', 'promedius_synthesized_cxr_001316.png', 'promedius_synthesized_cxr_000060.png', 'promedius_synthesized_cxr_001733.png', 'promedius_synthesized_cxr_000102.png', 'promedius_synthesized_cxr_001885.png']

# %%
#샘플 이미지 10장을 디스플레이해보기
import cv2
import matplotlib.pyplot as plt

for tmp in range(10):
  img=cv2.imread(os.path.join('handson_stylegan2ada/promedius_cxr_500_for_stylegan2ada_128pixel', imglist[tmp]), 0)#이미지 읽기
  plt.figure(figsize=(5,5))
  print(imglist[tmp])#이미지 파일명 출력하기
  plt.imshow(img, cmap='gray')#이미지 디스플레이하기
  plt.show()
# Out:
# promedius_synthesized_cxr_001662.png
# promedius_synthesized_cxr_001740.png
# promedius_synthesized_cxr_001756.png
# promedius_synthesized_cxr_001563.png
# promedius_synthesized_cxr_001281.png
# promedius_synthesized_cxr_001316.png
# promedius_synthesized_cxr_000060.png
# promedius_synthesized_cxr_001733.png
# promedius_synthesized_cxr_000102.png
# promedius_synthesized_cxr_001885.png

# %%
#Stylegan2ada에 맞는 입력 포맷으로 변환하기
# !python dataset_tool.py --source=handson_stylegan2ada/promedius_cxr_500_for_stylegan2ada_128pixel --dest=handson_stylegan2ada/promedius_cxr_500_for_stylegan2ada_128pixel.zip
# Out:
# 100% 500/500 [00:00<00:00, 544.76it/s]

# %%
#새로 만들어진 파일 확인하기
# !ls handson_stylegan2ada
# Out:
# promedius_cxr_500_for_stylegan2ada_128pixel
# promedius_cxr_500_for_stylegan2ada_128pixel.zip

# %%
#생성모델 학습하기
# !python train.py --outdir=./results --data=handson_stylegan2ada/promedius_cxr_500_for_stylegan2ada_128pixel.zip --gpus=1 --augpipe=bg --gamma=10 --cfg=auto --mirror=0 --snap=10 --resume=ffhq256
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 10,
#   "network_snapshot_ticks": 10,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "handson_stylegan2ada/promedius_cxr_500_for_stylegan2ada_128pixel.zip",
#     "use_labels": false,
#     "max_size": 500,
#     "xflip": false,
#     "resolution": 128
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 16384,
#     "channel_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 10.0
#   },
#   "total_kimg": 25000,
#   "batch_size": 32,
#   "batch_gpu": 32,
#   "ema_kimg": 10.0,
#   "ema_rampup": null,
#   "ada_target": 0.6,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1
#   },
#   "resume_pkl": "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/transfer-learning-source-nets/ffhq-res256-mirror-paper256-noaug.pkl",
#   "ada_kimg": 100,
#   "run_dir": "./results/00000-promedius_cxr_500_for_stylegan2ada_128pixel-auto1-gamma10-bg-resumeffhq256"
# }
#
# Output directory:   ./results/00000-promedius_cxr_500_for_stylegan2ada_128pixel-auto1-gamma10-bg-resumeffhq256
# Training data:      handson_stylegan2ada/promedius_cxr_500_for_stylegan2ada_128pixel.zip
# Training duration:  25000 kimg
# Number of GPUs:     1
# Number of images:   500
# Image resolution:   128
# Conditional model:  False
# Dataset x-flips:    False
#
# Creating output directory...
# Launching processes...
# Loading training set...
#
# Num images:  500
# Image shape: [3, 128, 128]
# Label shape: [0]
#
# Constructing networks...
# Resuming from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/transfer-learning-source-nets/ffhq-res256-mirror-paper256-noaug.pkl"
# Downloading https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/transfer-learning-source-nets/ffhq-res256-mirror-paper256-noaug.pkl ... done
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Generator             Parameters  Buffers  Output shape         Datatype
# ---                   ---         ---      ---                  ---
# mapping.fc0           262656      -        [32, 512]            float32
# mapping.fc1           262656      -        [32, 512]            float32
# mapping               -           512      [32, 12, 512]        float32
# synthesis.b4.conv1    2622465     32       [32, 512, 4, 4]      float32
# synthesis.b4.torgb    264195      -        [32, 3, 4, 4]        float32
# synthesis.b4:0        8192        16       [32, 512, 4, 4]      float32
# synthesis.b4:1        -           -        [32, 512, 4, 4]      float32
# synthesis.b8.conv0    2622465     80       [32, 512, 8, 8]      float32
# synthesis.b8.conv1    2622465     80       [32, 512, 8, 8]      float32
# synthesis.b8.torgb    264195      -        [32, 3, 8, 8]        float32
# synthesis.b8:0        -           16       [32, 512, 8, 8]      float32
# synthesis.b8:1        -           -        [32, 512, 8, 8]      float32
# synthesis.b16.conv0   2622465     272      [32, 512, 16, 16]    float16
# synthesis.b16.conv1   2622465     272      [32, 512, 16, 16]    float16
# synthesis.b16.torgb   264195      -        [32, 3, 16, 16]      float16
# synthesis.b16:0       -           16       [32, 512, 16, 16]    float16
# synthesis.b16:1       -           -        [32, 512, 16, 16]    float32
# synthesis.b32.conv0   2622465     1040     [32, 512, 32, 32]    float16
# synthesis.b32.conv1   2622465     1040     [32, 512, 32, 32]    float16
# synthesis.b32.torgb   264195      -        [32, 3, 32, 32]      float16
# synthesis.b32:0       -           16       [32, 512, 32, 32]    float16
# synthesis.b32:1       -           -        [32, 512, 32, 32]    float32
# synthesis.b64.conv0   1442561     4112     [32, 256, 64, 64]    float16
# synthesis.b64.conv1   721409      4112     [32, 256, 64, 64]    float16
# synthesis.b64.torgb   132099      -        [32, 3, 64, 64]      float16
# synthesis.b64:0       -           16       [32, 256, 64, 64]    float16
# synthesis.b64:1       -           -        [32, 256, 64, 64]    float32
# synthesis.b128.conv0  426369      16400    [32, 128, 128, 128]  float16
# synthesis.b128.conv1  213249      16400    [32, 128, 128, 128]  float16
# synthesis.b128.torgb  66051       -        [32, 3, 128, 128]    float16
# synthesis.b128:0      -           16       [32, 128, 128, 128]  float16
# synthesis.b128:1      -           -        [32, 128, 128, 128]  float32
# ---                   ---         ---      ---                  ---
# Total                 22949277    44448    -                    -
#
#
# Discriminator  Parameters  Buffers  Output shape         Datatype
# ---            ---         ---      ---                  ---
# b128.fromrgb   512         16       [32, 128, 128, 128]  float16
# b128.skip      32768       16       [32, 256, 64, 64]    float16
# b128.conv0     147584      16       [32, 128, 128, 128]  float16
# b128.conv1     295168      16       [32, 256, 64, 64]    float16
# b128           -           16       [32, 256, 64, 64]    float16
# b64.skip       131072      16       [32, 512, 32, 32]    float16
# b64.conv0      590080      16       [32, 256, 64, 64]    float16
# b64.conv1      1180160     16       [32, 512, 32, 32]    float16
# b64            -           16       [32, 512, 32, 32]    float16
# b32.skip       262144      16       [32, 512, 16, 16]    float16
# b32.conv0      2359808     16       [32, 512, 32, 32]    float16
# b32.conv1      2359808     16       [32, 512, 16, 16]    float16
# b32            -           16       [32, 512, 16, 16]    float16
# b16.skip       262144      16       [32, 512, 8, 8]      float16
# b16.conv0      2359808     16       [32, 512, 16, 16]    float16
# b16.conv1      2359808     16       [32, 512, 8, 8]      float16
# b16            -           16       [32, 512, 8, 8]      float16
# b8.skip        262144      16       [32, 512, 4, 4]      float32
# b8.conv0       2359808     16       [32, 512, 8, 8]      float32
# b8.conv1       2359808     16       [32, 512, 4, 4]      float32
# b8             -           16       [32, 512, 4, 4]      float32
# b4.mbstd       -           -        [32, 513, 4, 4]      float32
# b4.conv        2364416     16       [32, 512, 4, 4]      float32
# b4.fc          4194816     -        [32, 512]            float32
# b4.out         513         -        [32, 1]              float32
# ---            ---         ---      ---                  ---
# Total          23882369    352      -                    -
#
# Setting up augmentation...
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# Skipping tfevents export: TensorBoard logging requires TensorBoard version 1.15 or above
# Training for 25000 kimg...
#
# tick 0     kimg 0.0      time 1m 20s       sec/tick 7.9     sec/kimg 245.41  maintenance 72.5   cpumem 4.14   gpumem 11.42  augment 0.000
# Evaluating metrics...
#
# Aborted!
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f84d6ffb040>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/usr/lib/python3.8/multiprocessing/popen_fork.py", line 44, in wait
#     if not wait([self.sentinel], timeout):
#   File "/usr/lib/python3.8/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.8/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:

# %% [markdown]
# ###작업 로그 및 학습도중 저장된 모델 weight 확인해보기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###학습이 진행되면 아래와 같이 로그가 남음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !ls 'results'
# Out:
# 00000-promedius_cxr_500_for_stylegan2ada_128pixel-auto1-gamma10-bg-resumeffhq256

# %%
# !ls 'results/00000-promedius_cxr_500_for_stylegan2ada_128pixel-auto1-gamma10-bg-resumeffhq256'
# Out:
# fakes000000.png  network-snapshot-000000.pkl  training_options.json
# fakes_init.png	 reals.png
# log.txt		 stats.jsonl

# %%
# !ls 'handson_stylegan2ada'
# Out:
# promedius_cxr_500_for_stylegan2ada_128pixel
# promedius_cxr_500_for_stylegan2ada_128pixel.zip

# %%
# 미리 학습해둔 weight 다운받기
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=10vG_N6yLvzCcjefyyASXnvvW6OmjS5yh' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=10vG_N6yLvzCcjefyyASXnvvW6OmjS5yh" -O network-snapshot-011571.pkl && rm -rf ~/cookies.txt
# Out:
# --2023-01-06 12:51:26--  https://docs.google.com/uc?export=download&confirm=t&id=10vG_N6yLvzCcjefyyASXnvvW6OmjS5yh
# Resolving docs.google.com (docs.google.com)... 74.125.24.138, 74.125.24.102, 74.125.24.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.24.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0o-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ojlr4p3ndgdt7v7p45npr4njbo15313n/1673009475000/03948272884470799285/*/10vG_N6yLvzCcjefyyASXnvvW6OmjS5yh?e=download&uuid=8b0f9604-e743-40eb-b1bd-0a88d4a31609 [following]
# Warning: wildcards not supported in HTTP.
# --2023-01-06 12:51:26--  https://doc-0o-2o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ojlr4p3ndgdt7v7p45npr4njbo15313n/1673009475000/03948272884470799285/*/10vG_N6yLvzCcjefyyASXnvvW6OmjS5yh?e=download&uuid=8b0f9604-e743-40eb-b1bd-0a88d4a31609
# Resolving doc-0o-2o-docs.googleusercontent.com (doc-0o-2o-docs.googleusercontent.com)... 142.251.12.132, 2404:6800:4003:c11::84
# Connecting to doc-0o-2o-docs.googleusercontent.com (doc-0o-2o-docs.googleusercontent.com)|142.251.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 283134230 (270M) [application/octet-stream]
# Saving to: ‘network-snapshot-011571.pkl’
#
# network-snapshot-01 100%[===================>] 270.02M   240MB/s    in 1.1s
#
# 2023-01-06 12:51:27 (240 MB/s) - ‘network-snapshot-011571.pkl’ saved [283134230/283134230]

# %%
# !ls
# Out:
# calc_metrics.py  handson_stylegan2ada	      __pycache__
# dataset_tool.py  handson_stylegan2ada.zip     README.md
# dnnlib		 legacy.py		      results
# Dockerfile	 LICENSE.txt		      style_mixing.py
# docker_run.sh	 metrics		      torch_utils
# docs		 network-snapshot-011571.pkl  training
# generate.py	 projector.py		      train.py

# %%
#미리 학습해둔 weight로 합성 이미지 만들기(trunc: 합성 이미지의 분포 넓이. 0에 가까울수록 분포가 좁아짐. 1은 truncation을 사용하지 않은 것과 동일 효과)
# !python generate.py --outdir generated_images --trunc=0.1 --seeds=10 --network 'network-snapshot-011571.pkl'
# Out:
# Loading networks from "network-snapshot-011571.pkl"...
# Generating image for seed 10 (0/1) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.

# %%
#합성한 이미지 파일 체크해보기
os.listdir('generated_images')
# Out:
# ['seed0010.png']

# %%
#합성한 이미지 디스플레이 해보기(참고: 학습이 충분히 되지 않음. 1024x1024-pixel 이미지를 생성시 StyleGAN2-ADA의 경우 GPU 24GB하나를 사용했을때 대략 2주일 정도 소요됨)
syn_img=cv2.imread('generated_images/seed0010.png', 0)
plt.figure(figsize=(10,10))
plt.imshow(syn_img, cmap='gray')
plt.show()

# %%
# !ls
# Out:
# calc_metrics.py   handson_stylegan2ada	       README.md
# dataset_tool.py   handson_stylegan2ada.zip     results
# dnnlib		  legacy.py		       style_mixing.py
# Dockerfile	  LICENSE.txt		       torch_utils
# docker_run.sh	  metrics		       training
# docs		  network-snapshot-011571.pkl  train.py
# generated_images  projector.py
# generate.py	  __pycache__

# %%
# !python generate.py --outdir generated_images --trunc=0.1 --seeds=10 --network './results/00000-promedius_cxr_500_for_stylegan2ada_128pixel-auto1-gamma10-bg-resumeffhq256/network-snapshot-000000.pkl'
# Out:
# Loading networks from "./results/00000-promedius_cxr_500_for_stylegan2ada_128pixel-auto1-gamma10-bg-resumeffhq256/network-snapshot-000000.pkl"...
# Generating image for seed 10 (0/1) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.

# %%
#합성한 이미지 파일 체크해보기
os.listdir('generated_images')
# Out:
# ['seed0010.png']

# %%
#합성한 이미지 디스플레이 해보기(참고: 학습이 충분히 되지 않음. 1024x1024-pixel 이미지를 생성시 StyleGAN2-ADA의 경우 GPU 24GB하나를 사용했을때 대략 2주일 정도 소요됨)
syn_img=cv2.imread('generated_images/seed0010.png', 0)
plt.figure(figsize=(10,10))
plt.imshow(syn_img, cmap='gray')
plt.show()
